# %% [markdown]
# <a href="https://colab.research.google.com/github/vangakarthik/OIBSIP/blob/main/cleaning_data.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df=pd.read_csv("/content/AB_NYC_2019.csv")

# %%
data=df.copy()
data.head(3)
# Out:
#      id                                 name  host_id  host_name  \
# 0  2539   Clean & quiet apt home by the park   2787.0       John
# 1  2595                Skylit Midtown Castle   2845.0   Jennifer
# 2  3647  THE VILLAGE OF HARLEM....NEW YORK !   4632.0  Elisabeth
#
#   neighbourhood_group neighbourhood  latitude  longitude        room_type  \
# 0            Brooklyn    Kensington  40.64749  -73.97237     Private room
# 1           Manhattan       Midtown  40.75362  -73.98377  Entire home/apt
# 2           Manhattan        Harlem  40.80902  -73.94190     Private room
#
#    price  minimum_nights  number_of_reviews last_review  reviews_per_month  \
# 0  149.0             1.0                9.0  2018-10-19               0.21
# 1  225.0             1.0               45.0  2019-05-21               0.38
# 2  150.0             3.0                0.0         NaN                NaN
#
#    calculated_host_listings_count  availability_365
# 0                             6.0             365.0
# 1                             2.0             355.0
# 2                             1.0             365.0

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 43427 entries, 0 to 43426
# Data columns (total 16 columns):
#  #   Column                          Non-Null Count  Dtype
# ---  ------                          --------------  -----
#  0   id                              43427 non-null  int64
#  1   name                            43411 non-null  object
#  2   host_id                         43426 non-null  float64
#  3   host_name                       43405 non-null  object
#  4   neighbourhood_group             43426 non-null  object
#  5   neighbourhood                   43426 non-null  object
#  6   latitude                        43426 non-null  float64
#  7   longitude                       43426 non-null  float64
#  8   room_type                       43426 non-null  object
#  9   price                           43426 non-null  float64
#  10  minimum_nights                  43426 non-null  float64
#  11  number_of_reviews               43426 non-null  float64
#  12  last_review                     36053 non-null  object
#  13  reviews_per_month               36053 non-null  float64
#  14  calculated_host_listings_count  43426 non-null  float64
#  15  availability_365                43426 non-null  float64
# dtypes: float64(9), int64(1), object(6)
# memory usage: 5.3+ MB

# %%
data.isnull().sum()
# Out:
# id                                   0
# name                                16
# host_id                              1
# host_name                           22
# neighbourhood_group                  1
# neighbourhood                        1
# latitude                             1
# longitude                            1
# room_type                            1
# price                                1
# minimum_nights                       1
# number_of_reviews                    1
# last_review                       7374
# reviews_per_month                 7374
# calculated_host_listings_count       1
# availability_365                     1
# dtype: int64

# %%
data.duplicated().sum()
# Out:
# 0

# %%
data.dropna(subset=['name','host_name','last_review','reviews_per_month'],inplace=True)

# %%
data.isnull().sum()
# Out:
# id                                0
# name                              0
# host_id                           0
# host_name                         0
# neighbourhood_group               0
# neighbourhood                     0
# latitude                          0
# longitude                         0
# room_type                         0
# price                             0
# minimum_nights                    0
# number_of_reviews                 0
# last_review                       0
# reviews_per_month                 0
# calculated_host_listings_count    0
# availability_365                  0
# dtype: int64

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 36031 entries, 0 to 43425
# Data columns (total 16 columns):
#  #   Column                          Non-Null Count  Dtype
# ---  ------                          --------------  -----
#  0   id                              36031 non-null  int64
#  1   name                            36031 non-null  object
#  2   host_id                         36031 non-null  float64
#  3   host_name                       36031 non-null  object
#  4   neighbourhood_group             36031 non-null  object
#  5   neighbourhood                   36031 non-null  object
#  6   latitude                        36031 non-null  float64
#  7   longitude                       36031 non-null  float64
#  8   room_type                       36031 non-null  object
#  9   price                           36031 non-null  float64
#  10  minimum_nights                  36031 non-null  float64
#  11  number_of_reviews               36031 non-null  float64
#  12  last_review                     36031 non-null  object
#  13  reviews_per_month               36031 non-null  float64
#  14  calculated_host_listings_count  36031 non-null  float64
#  15  availability_365                36031 non-null  float64
# dtypes: float64(9), int64(1), object(6)
# memory usage: 4.7+ MB

# %%
data.head(3)
# Out:
#      id                                name  host_id    host_name  \
# 0  2539  Clean & quiet apt home by the park   2787.0         John
# 1  2595               Skylit Midtown Castle   2845.0     Jennifer
# 3  3831     Cozy Entire Floor of Brownstone   4869.0  LisaRoxanne
#
#   neighbourhood_group neighbourhood  latitude  longitude        room_type  \
# 0            Brooklyn    Kensington  40.64749  -73.97237     Private room
# 1           Manhattan       Midtown  40.75362  -73.98377  Entire home/apt
# 3            Brooklyn  Clinton Hill  40.68514  -73.95976  Entire home/apt
#
#    price  minimum_nights  number_of_reviews last_review  reviews_per_month  \
# 0  149.0             1.0                9.0  2018-10-19               0.21
# 1  225.0             1.0               45.0  2019-05-21               0.38
# 3   89.0             1.0              270.0  2019-07-05               4.64
#
#    calculated_host_listings_count  availability_365
# 0                             6.0             365.0
# 1                             2.0             355.0
# 3                             1.0             194.0

# %%
c=data['room_type'].value_counts()
c
# Out:
# room_type
# Entire home/apt    18804
# Private room       16491
# Shared room          736
# Name: count, dtype: int64

# %%
import matplotlib.pyplot as plt
fig, ax = plt.subplots()
ax.bar(c.index, c.values)
ax.set_xlabel('Room_Types')
ax.set_ylabel('Values')
ax.set_title('Room_type_values')
plt.show()

# %%
d=data['host_name'].value_counts().nlargest(10)
d
# Out:
# host_name
# Michael         308
# David           269
# John            235
# Alex            194
# Sarah           176
# Jessica         163
# Daniel          160
# Sonder (NYC)    158
# Maria           154
# Anna            151
# Name: count, dtype: int64

# %%
import matplotlib.pyplot as plt
plt.figure(figsize=[10,5])
fig, ax = plt.subplots()
ax.bar(d.index, d.values)
ax.set_xlabel('host_name')
ax.set_ylabel('count')
ax.set_title('host_name_values')
plt.xticks(rotation=45)
plt.show()

# %%
data.head(3)
# Out:
#      id                                name  host_id    host_name  \
# 0  2539  Clean & quiet apt home by the park   2787.0         John
# 1  2595               Skylit Midtown Castle   2845.0     Jennifer
# 3  3831     Cozy Entire Floor of Brownstone   4869.0  LisaRoxanne
#
#   neighbourhood_group neighbourhood  latitude  longitude        room_type  \
# 0            Brooklyn    Kensington  40.64749  -73.97237     Private room
# 1           Manhattan       Midtown  40.75362  -73.98377  Entire home/apt
# 3            Brooklyn  Clinton Hill  40.68514  -73.95976  Entire home/apt
#
#    price  minimum_nights  number_of_reviews last_review  reviews_per_month  \
# 0  149.0             1.0                9.0  2018-10-19               0.21
# 1  225.0             1.0               45.0  2019-05-21               0.38
# 3   89.0             1.0              270.0  2019-07-05               4.64
#
#    calculated_host_listings_count  availability_365
# 0                             6.0             365.0
# 1                             2.0             355.0
# 3                             1.0             194.0

# %%
df = data[['host_name', 'room_type']]
df
# Out:
#               host_name        room_type
# 0                  John     Private room
# 1              Jennifer  Entire home/apt
# 3           LisaRoxanne  Entire home/apt
# 4                 Laura  Entire home/apt
# 5                 Chris  Entire home/apt
# ...                 ...              ...
# 43420            Robert  Entire home/apt
# 43421  Kateryna And Tim     Private room
# 43422             Grace     Private room
# 43423              Matt     Private room
# 43425            Rachel     Private room
#
# [36031 rows x 2 columns]

# %%
data.groupby('host_name')['room_type'].sum()
# Out:
# host_name
# 'Cil                                                             Private room
# (Ari) HENRY LEE                                               Entire home/apt
# (Email hidden by Airbnb)    Private roomEntire home/aptEntire home/aptPriv...
# (Mary) Haiy                                                   Entire home/apt
# -TheQueensCornerLot                                           Entire home/apt
#                                                   ...
# 美德                          Private roomPrivate roomPrivate roomShared roo...
# 诗月                                                               Private room
# 青明                          Private roomPrivate roomPrivate roomPrivate ro...
# 빈나                                                               Private room
# 소정                                                               Private room
# Name: room_type, Length: 9287, dtype: object

# %%
host_name=data['host_name'].value_counts().sort_values(ascending=False).head(10)

plt.figure(figsize=[10,5])
sns.countplot(data=df,
             x='host_name',
             order=host_name.index,
             hue='room_type');
plt.title('Top 10 room type counts');

# %%
data.head(3)
# Out:
#      id                                name  host_id    host_name  \
# 0  2539  Clean & quiet apt home by the park   2787.0         John
# 1  2595               Skylit Midtown Castle   2845.0     Jennifer
# 3  3831     Cozy Entire Floor of Brownstone   4869.0  LisaRoxanne
#
#   neighbourhood_group neighbourhood  latitude  longitude        room_type  \
# 0            Brooklyn    Kensington  40.64749  -73.97237     Private room
# 1           Manhattan       Midtown  40.75362  -73.98377  Entire home/apt
# 3            Brooklyn  Clinton Hill  40.68514  -73.95976  Entire home/apt
#
#    price  minimum_nights  number_of_reviews last_review  reviews_per_month  \
# 0  149.0             1.0                9.0  2018-10-19               0.21
# 1  225.0             1.0               45.0  2019-05-21               0.38
# 3   89.0             1.0              270.0  2019-07-05               4.64
#
#    calculated_host_listings_count  availability_365
# 0                             6.0             365.0
# 1                             2.0             355.0
# 3                             1.0             194.0

# %%
plt.figure(figsize=[12,6])
sns.scatterplot(y=data['price'],
               x=data['number_of_reviews'],
               hue=data['room_type']
               )
plt.title('Relation between Price and Number of reviews')

plt.xticks(range(0,1300,100))
plt.yticks(range(0,12000,1000))
plt.show()

# %%
availability=data.groupby('neighbourhood_group')['availability_365'].mean()
availability
# Out:
# neighbourhood_group
# Bronx            170.176697
# Brooklyn         103.838841
# Manhattan        105.706793
# Queens           146.715703
# Staten Island    212.143357
# Name: availability_365, dtype: float64
